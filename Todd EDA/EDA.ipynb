# %% [markdown]
# # Step one Parametrize missing data

# %%
import pandas as pd
import os
while(not os.getcwd().endswith('Dule_Gasifier_ML')):
    #back out of directory   
    os.chdir('..')

os.getcwd()
# print(os.getcwd())
# os.chdir('..')
# print(os.getcwd())
# Out:
# 'c:\\Users\\theto\\OneDrive\\Desktop\\DS\\Dule_Gasifier_ML'

# %%
# read in cleaned data
df = pd.read_csv(r"Data\filtered_combine_data.csv")
df.describe()
# Out:
#          Unnamed: 0  EFG Air Flow Rate lb/hr  EFG Gas Flow Rate lb/hr  \
# count  16556.000000             16556.000000             16556.000000
# mean    8277.500000                15.507516                 0.058138
# std     4779.449864                 0.710216                 0.122002
# min        0.000000                 0.000000                 0.000000
# 25%     4138.750000                15.387000                 0.000000
# 50%     8277.500000                15.563000                 0.000000
# 75%    12416.250000                15.700000                 0.000000
# max    16555.000000                15.984000                 0.491000
#
#        Primary O2 Flow Rate lb/hr  EFG System Pressure psi  \
# count                16556.000000             16556.000000
# mean                    49.326159               148.458696
# std                     12.288293                65.246174
# min                     -0.238000                -0.083000
# 25%                     49.962000               147.005000
# 50%                     52.925000               150.167000
# 75%                     54.988000               151.476000
# max                     61.312000               254.187000
#
#        EFG Reactor dP inH2O  Slurry Flow Rate lb/hr  \
# count          16556.000000            16556.000000
# mean              -1.153694               94.772466
# std                1.019741               25.385379
# min               -2.423000               -2.580000
# 25%               -2.400000               96.660000
# 50%               -0.405000              105.185000
# 75%               -0.322000              106.400000
# max                0.210000              152.400000
#
#        Injector Cooling Water Outlet Temp F  EFG:Hot_Hold_HSR       EFG:HSR  \
# count                          16556.000000      16556.000000  16556.000000
# mean                           -1169.555558      99071.835313   3079.954963
# std                             6264.093565      57598.974918    918.913219
# min                           -32768.000000        -94.058000     -2.811000
# 25%                               69.236000      36300.602000   2676.742000
# 50%                               72.784000     130437.555000   3245.659000
# 75%                               75.612000     137773.031000   3743.792000
# max                               84.911000     153196.047000   5210.533000
#
#        ...  Afterburner Sec 3 Temp F  Afterburner Sec 4 Temp F  \
# count  ...              16556.000000              16556.000000
# mean   ...               1715.787957               1602.307693
# std    ...                145.901070                146.296806
# min    ...               1211.017000               1059.251000
# 25%    ...               1638.956500               1526.796000
# 50%    ...               1724.391500               1620.122000
# 75%    ...               1807.636000               1695.737500
# max    ...               2008.610000               1881.911000
#
#        Afterburner Flue Inlet Temp F  Afterburner Flue Outlet Temp F  \
# count                   16556.000000                    16556.000000
# mean                      528.123243                      206.781822
# std                        64.394771                       21.283725
# min                       244.716000                       92.535000
# 25%                       501.514000                      204.253000
# 50%                       539.127000                      212.252000
# 75%                       567.670000                      216.599000
# max                       648.066000                      267.119000
#
#        EFG Quenched Gas Temp F  Sparger Flow Rate gal/min  \
# count             16556.000000               16556.000000
# mean                280.347519                  21.402493
# std                  45.097492                   5.485925
# min                  92.227000                   0.035000
# 25%                 273.073000                  22.430000
# 50%                 288.195000                  22.610000
# 75%                 305.701000                  22.795000
# max                 333.730000                  30.595000
#
#        Quench Spray Flow Rate gal/hr  EFG Badger Reading %  \
# count                   16556.000000          16556.000000
# mean                       24.858510             49.488931
# std                         3.942373             12.679705
# min                         6.700000             19.280000
# 25%                        22.168000             39.928750
# 50%                        22.398000             46.767500
# 75%                        26.976000             57.340000
# max                        32.908000             85.095000
#
#        Flue Gas Outlet Temp F  EFG:B_TC_1_Shallow.Value
# count            16556.000000              16556.000000
# mean               202.220992               2253.071636
# std                 28.714088                197.066697
# min                100.600000               1683.589000
# 25%                188.385000               2167.692000
# 50%                205.252000               2215.962000
# 75%                219.294000               2319.970750
# max                255.829000               3013.320000
#
# [8 rows x 42 columns]

# %%
def find_missing
